# %%
# Out:
# Failed to start the Kernel.
#
# Bad file descriptor (C:\Users\runneradmin\AppData\Local\Temp\tmp66uptq0j\build\_deps\bundled_libzmq-src\src\epoll.cpp:73).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
